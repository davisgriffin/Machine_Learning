# %% [markdown]
# ## Predicting Beer Reviews
# > Griffin Davis and Sydnee Haney

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error as MAPE

# %% [markdown]
# #### Load in Data

# %%
fr = open('../Datasets/beer_ratings.json', 'r')
beer_ratings = pd.read_json(fr, orient='records')
fr.close()
X = beer_ratings[['beer/ABV', 'user/ageInSeconds',
                  'user/gender', 'beer/style', 'review/overall']]
X = X.dropna()
y = X['review/overall']
X.drop(columns='review/overall', inplace=True)
X = pd.get_dummies(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
X
# Out:
#        beer/ABV  user/ageInSeconds  user/gender_Female  user/gender_Male  \
# 4           7.7       3.581417e+09                   0                 1
# 16          5.6       1.782054e+09                   0                 1
# 21          7.4       9.833726e+08                   0                 1
# 25          7.4       1.263823e+09                   0                 1
# 30          7.4       8.931710e+08                   0                 1
# ...         ...                ...                 ...               ...
# 49947       9.0       1.031667e+09                   1                 0
# 49951       9.0       1.284822e+09                   0                 1
# 49956       9.0       8.941214e+08                   0                 1
# 49964       9.0       9.497594e+08                   0                 1
# 49974       9.0       1.066054e+09                   0                 1
#
#        beer/style_Altbier  beer/style_American Adjunct Lager  \
# 4                       0                                  0
# 16                      0                                  0
# 21                      0                                  0
# 25                      0                                  0
# 30                      0                                  0
# ...                   ...                                ...
# 49947                   0                                  0
# 49951                   0                                  0
# 49956                   0                                  0
# 49964                   0                                  0
# 49974                   0                                  0
#
#        beer/style_American Amber / Red Ale  \
# 4                                        0
# 16                                       0
# 21                                       0
# 25                                       0
# 30                                       0
# ...                                    ...
# 49947                                    0
# 49951                                    0
# 49956                                    0
# 49964                                    0
# 49974                                    0
#
#        beer/style_American Amber / Red Lager  beer/style_American Barleywine  \
# 4                                          0                               0
# 16                                         0                               0
# 21                                         0                               0
# 25                                         0                               0
# 30                                         0                               0
# ...                                      ...                             ...
# 49947                                      0                               0
# 49951                                      0                               0
# 49956                                      0                               0
# 49964                                      0                               0
# 49974                                      0                               0
#
#        beer/style_American Black Ale  ...  beer/style_Schwarzbier  \
# 4                                  0  ...                       0
# 16                                 0  ...                       0
# 21                                 0  ...                       0
# 25                                 0  ...                       0
# 30                                 0  ...                       0
# ...                              ...  ...                     ...
# 49947                              0  ...                       0
# 49951                              0  ...                       0
# 49956                              0  ...                       0
# 49964                              0  ...                       0
# 49974                              0  ...                       0
#
#        beer/style_Scotch Ale / Wee Heavy  beer/style_Scottish Ale  \
# 4                                      0                        0
# 16                                     0                        0
# 21                                     0                        0
# 25                                     0                        0
# 30                                     0                        0
# ...                                  ...                      ...
# 49947                                  0                        0
# 49951                                  0                        0
# 49956                                  0                        0
# 49964                                  0                        0
# 49974                                  0                        0
#
#        beer/style_Scottish Gruit / Ancient Herbed Ale  beer/style_Smoked Beer  \
# 4                                                   0                       0
# 16                                                  0                       0
# 21                                                  0                       0
# 25                                                  0                       0
# 30                                                  0                       0
# ...                                               ...                     ...
# 49947                                               0                       0
# 49951                                               0                       0
# 49956                                               0                       0
# 49964                                               0                       0
# 49974                                               0                       0
#
#        beer/style_Tripel  beer/style_Vienna Lager  beer/style_Wheatwine  \
# 4                      0                        0                     0
# 16                     0                        0                     0
# 21                     0                        0                     0
# 25                     0                        0                     0
# 30                     0                        0                     0
# ...                  ...                      ...                   ...
# 49947                  0                        0                     0
# 49951                  0                        0                     0
# 49956                  0                        0                     0
# 49964                  0                        0                     0
# 49974                  0                        0                     0
#
#        beer/style_Winter Warmer  beer/style_Witbier
# 4                             0                   0
# 16                            0                   0
# 21                            0                   0
# 25                            0                   0
# 30                            0                   0
# ...                         ...                 ...
# 49947                         0                   0
# 49951                         0                   0
# 49956                         0                   0
# 49964                         0                   0
# 49974                         0                   0
#
# [10279 rows x 95 columns]

# %% [markdown]
# #### Create Linear Model

# %%
model = LinearRegression().fit(X_train, y_train)
prediction = model.predict(X_test)
score = model.score(X_test, y_test)
print('''R^2: {:.4f}
Mean Absolute Percentage Error: {:.4f}%'''.format(score, MAPE(y_test, prediction)*100))
# Out:
# R^2: 0.1857
# Mean Absolute Percentage Error: 14.1772%

# %% [markdown]
# #### Visualizing Predictions

# %%
plt.close('all')
x = np.arange(0, len(prediction))
fig, ax = plt.subplots()
ax.plot(x[1000:1100], prediction[1000:1100], label='Prediction')
ax.plot(x[1000:1100], y_test[1000:1100], label='Test Data')
ax.set_xlabel('Data Points')
ax.set_ylabel('Ratings')
fig.suptitle('Beer Rating Regression')
ax.legend()
plt.show()
